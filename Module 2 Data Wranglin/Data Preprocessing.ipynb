# %%
# Data cleaning and wrangling is the same thing
# Make raw data usable
# 1. identify missing data 2. Data Formatting 3.Data Normalization(centering and scaling) 4.Data Binning 
# 5. Turning Categroical Variables to Numeric Variables

# %%
import pandas as pd
path="C:\\Users\\ARNOB\\Desktop\\Automobile.csv"
df=pd.read_csv(path)

# %%
df["symboling"]
# Out:
# 0      3
# 1      3
# 2      1
# 3      2
# 4      2
#       ..
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# 204   -1
# Name: symboling, Length: 205, dtype: int64

# %%
#Additioning works like a grid in pandas
df["symboling"]+1
# Out:
# 0      4
# 1      4
# 2      2
# 3      3
# 4      3
#       ..
# 200    0
# 201    0
# 202    0
# 203    0
# 204    0
# Name: symboling, Length: 205, dtype: int64

# %%
df['symboling']=df['symboling']+1

# %%
df
# Out:
#      Unnamed: 0  symboling normalized losses         make fuel type  \
# 0             0          4                 ?  alfa-romero       gas
# 1             1          4                 ?  alfa-romero       gas
# 2             2          2                 ?  alfa-romero       gas
# 3             3          3               164         audi       gas
# 4             4          3               164         audi       gas
# ..          ...        ...               ...          ...       ...
# 200         200          0                95        volvo       gas
# 201         201          0                95        volvo       gas
# 202         202          0                95        volvo       gas
# 203         203          0                95        volvo    diesel
# 204         204          0                95        volvo       gas
#
#     aspiration door numbers  body styles drive wheels engine location  ...  \
# ...
