# %%
#So what to do when there is a missing data:
#1.Drop the missing values (WASTEFUL): i.drop the variable ii.drop the data entry
#2.Replace it (Reduces Accuracy): i. average value of similar datapoints ii.replace with frequency iii. replace wit other functions
#3. Leave it as missing data

# %%
import pandas as pd
import numpy as np
#We WILL USE A SEARCH GENERATOR HERE!!!!!!omggg!!! CSV NEEDS BLOODY SEARCHING AND REPLACEMENTSSSSSS
path="C:\\Users\\ARNOB\\Desktop\\Automobile.csv"
text=open(path,"r+")
text=''.join([i for i in text]).replace("?","NaN")
x = open(path,"w")
x.writelines(text)
x.close()
df=pd.read_csv(path)

# %%
df1=df.dropna(axis=0) #'inplace' can be used to permanently update df.dropna(subset="price or whatever",axis=0 or 1,inplace=True or False)
#dropna(axis=0 drops rows with NaN,NaT etc.. MAKE SURE YOU CHECK THIS!!!)
#dropna(axis=1 drops columns with Nan)

# %%
#df.dropna(axis=0)

# %%
#df.dropna(axis=1)

# %%
df1.loc[1:10,:] #Note that .loc still refers to the initial indexing (why?!!! unless it just counts the left most cell, verify!!)
# Out:
#     symboling  normalized losses  make fuel type aspiration door numbers  \
# 3           2              164.0  audi       gas        std         four
# 4           2              164.0  audi       gas        std         four
# 6           1              158.0  audi       gas        std         four
# 8           1              158.0  audi       gas      turbo         four
# 10          2              192.0   bmw       gas        std          two
#
#    body styles drive wheels engine location  wheel base  ...  engine size  \
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
# 6        sedan          fwd           front       105.8  ...          136
# 8        sedan          fwd           front       105.8  ...          131
# 10       sedan          rwd           front       101.2  ...          108
#
#     fuel system  bore  stroke compression ratio horsepower  peak rpm city mpg  \
# ...

# %%
df1.head(10) #However note that the head function acts using the new ordering sequence!!
# Out:
#     symboling  normalized losses       make fuel type aspiration door numbers  \
# 3           2              164.0       audi       gas        std         four
# 4           2              164.0       audi       gas        std         four
# 6           1              158.0       audi       gas        std         four
# 8           1              158.0       audi       gas      turbo         four
# 10          2              192.0        bmw       gas        std          two
# 11          0              192.0        bmw       gas        std         four
# 12          0              188.0        bmw       gas        std          two
# 13          0              188.0        bmw       gas        std         four
# 18          2              121.0  chevrolet       gas        std          two
# 19          1               98.0  chevrolet       gas        std          two
#
#    body styles drive wheels engine location  wheel base  ...  engine size  \
# ...

# %%
df
# Out:
#      symboling  normalized losses         make fuel type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     door numbers  body styles drive wheels engine location  wheel base  ...  \
# ...

# %%
#now replacing missing values
#df.replace(missing_value, new_value)df2=df.replace()
#replacing with mean value
mean=df["normalized losses"].mean()
df["normalized losses"].replace(np.nan,mean)
# Out:
# 0      122.0
# 1      122.0
# 2      122.0
# 3      164.0
# 4      164.0
#        ...
# 200     95.0
# 201     95.0
# 202     95.0
# 203     95.0
# 204     95.0
# Name: normalized losses, Length: 205, dtype: float64
