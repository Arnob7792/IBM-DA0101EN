# %%
#Data Formatting
import pandas as pd
import numpy as np
path="C:\\Users\\ARNOB\\Desktop\\Automobile.csv"
df=pd.read_csv(path)

# %%
#Just converting unit here
df["city mpg"]=235/df["city mpg"]

# %%
#Renaming columns here
df.rename(columns={"city mpg":"city L/100KM"},inplace=True)
df
# Out:
#      symboling  normalized losses         make fuel type aspiration  \
# 0            3                NaN  alfa-romero       gas        std
# 1            3                NaN  alfa-romero       gas        std
# 2            1                NaN  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# ..         ...                ...          ...       ...        ...
# 200         -1               95.0        volvo       gas        std
# 201         -1               95.0        volvo       gas      turbo
# 202         -1               95.0        volvo       gas        std
# 203         -1               95.0        volvo    diesel      turbo
# 204         -1               95.0        volvo       gas      turbo
#
#     door numbers  body styles drive wheels engine location  wheel base  ...  \
# ...

# %%
df["price"].tail(5)
# Out:
# 200    16845.0
# 201    19045.0
# 202    21485.0
# 203    22470.0
# 204    22625.0
# Name: price, dtype: float64

# %%
#Correctng data types
print(df.dtypes)
# Out:
# symboling              int64
# normalized losses    float64
# make                  object
# fuel type             object
# aspiration            object
# door numbers          object
# body styles           object
# drive wheels          object
# engine location       object
# wheel base           float64
# length               float64
# width                float64
# height               float64
# curb weight            int64
# engine type           object
# num of chylinders     object
# engine size            int64
# fuel system           object
# bore                 float64
# stroke               float64
# compression ratio    float64
# horsepower           float64
# peak rpm             float64
# city L/100KM         float64
# highway mpg            int64
# price                float64
# dtype: object

# %%
#convert data types
mean=df["price"].mean()
df=df.fillna(mean) #We HAVE TO FILL UP THE NaN slots. Otherwise type conversion will not work

# %%
df["price"]=df["price"].astype(int)

# %%
print(df["price"].dtypes)
# Out:
# int32
